# %% [markdown]
# # Testing the Integrated Simulation Platform
# This notebook contains codes to test the various functionalities of the integrated simulation platform. You can call any of the modules from the package here.

# %%
#Go to the main directory
#!pip install --editable . 
#!pip install pandas
# !pip install wntr
# !pip install pandapower
# !pip install sklearn

#to find requirements
#depfinder -y .

# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# C:\Users\sbalakrishna\AppData\Local\Temp\ipykernel_23532\3341618488.py:7: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Import required packages

# %%
from pathlib import Path
from infrarisk.src.network_recovery import *
import infrarisk.src.simulation as simulation
from infrarisk.src.physical.integrated_network import *
import infrarisk.src.recovery_strategies as strategies

from infrarisk.src.physical.interdependencies import *

from infrarisk.src.optimizer import *
import infrarisk.src.plots as model_plots

#hide warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Create an IntegratedNetwork object

# %%
micropolis_network = IntegratedNetwork(name = 'Micropolis')

# %% [markdown]
# ### Load the three infrastructure models: Water, Power and Transportation
#
# Three different models are used:
# - Water distribution network using **wntr** package
# - Power systems using **pandapower** package
# - Transportation network using static traffic assignment package developed by Dr. Stephen Boyles (University of Texas at Austin)

# %%
MAIN_DIR = Path('../..')
SIM_STEP = 60
network_dir= 'infrarisk/data/networks/micropolis'
water_folder = MAIN_DIR/f'{network_dir}/water/med'
power_folder = MAIN_DIR/f'{network_dir}/power/low'
transp_folder = MAIN_DIR/f'{network_dir}/transportation/high'

# load all infrastructure networks
micropolis_network.load_networks(water_folder, 
                                 power_folder, 
                                 transp_folder, 
                                 sim_step=SIM_STEP)
# Out:
# Water network successfully loaded from ..\..\infrarisk\data\networks\micropolis\water\med/water.inp. The analysis type is set to PDA.
# initial simulation duration: 60s; hydraulic time step: 60s; pattern time step: 3600s
#
# Power system successfully loaded from ..\..\infrarisk\data\networks\micropolis\power\low\power.json. Single phase power flow simulation will be used.
#
# Transportation network successfully loaded from ..\..\infrarisk\data\networks\micropolis\transportation\high. Static traffic assignment method will be used to calculate travel times.

# %% [markdown]
# ### Create a Networkx graph of the integrated infrastructure network.

# %%
micropolis_network.generate_integrated_graph()
# Out:
# Successfully added power network to the integrated graph...
# Successfully added water network to the integrated graph...
# Successfully added transportation network to the integrated graph...
# Integrated graph successffully created.
# Generating betweenness centrality...
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="9d83dc2d-50b9-4894-b590-22ce257f0541" data-root-id="1004"></div>

# %% [markdown]
# ### Build interdependencies
#
# Three types of dependencies:
# - Power - Water dependencies (eg.: water pump on electric motor, generator on reservoir)
# - Power - Transportation dependencies (eg.: road access to power system components for M&R)
# - Water - Transportation dependencies (eg.: road access to water network components for M&R)
#
# The dependencies are referenced using two tables in the model.
# - **wp_table** for water - power dependencies
# - **access_table** for transportation dependencies

# %%
dependency_file = MAIN_DIR/f"{network_dir}/dependencies.csv"
micropolis_network.generate_dependency_table(dependency_file = dependency_file)
micropolis_network.dependency_table.wp_table
# Out:
#   water_id power_id water_type power_type
# 0    W_WP1    P_MP1       Pump      Motor
# 1    W_WP2    P_MP1       Pump      Motor
# 2    W_WP3    P_MP1       Pump      Motor
# 3    W_WP4    P_MP1       Pump      Motor
# 4    W_WP5    P_MP2       Pump      Motor
# 5    W_WP6    P_MP2       Pump      Motor
# 6    W_WP7    P_MP2       Pump      Motor
# 7    W_WP8    P_MP3       Pump      Motor

# %%
micropolis_network.dependency_table.access_table.head()
# Out:
#   origin_id transp_id origin_cat origin_type  access_dist
# 0      P_B0     T_J57      power         Bus        84.79
# 1      P_B1     T_J57      power         Bus        16.96
# 2      P_B2     T_J57      power         Bus       178.04
# 3      P_B3     T_J56      power         Bus        27.57
# 4      P_B4     T_J56      power         Bus       170.80

# %%
# dill.dump_session('sessions/micropolis_no_optimization.db')
# dill.load_session('sessions/micropolis_no_optimization.db')

# %% [markdown]
# ### Set failed components

# %%
scenario_folder = "scenarios/track1"
disruption_file = MAIN_DIR/f"{network_dir}/{scenario_folder}/disruption_file.csv"

micropolis_network.set_disrupted_components(disruption_file=disruption_file)
micropolis_network.get_disrupted_components()
# Out:
# ['W_PMA732',
#  'W_PMA647',
#  'W_PMA549',
#  'W_PMA524',
#  'W_PMA802',
#  'P_L340',
#  'P_L333',
#  'P_L56',
#  'P_L310',
#  'P_L325',
#  'T_L72',
#  'T_L80',
#  'T_L86',
#  'T_L79']

# %% [markdown]
# ### Deploy recovery crews
# We can deploy as many repairs crews as possible. However, beyond a point, increasing the number of crews will not improve the performance of the system.

# %%
crew_count = 1
micropolis_network.deploy_crews(
    init_power_crew_locs=['T_J8']*crew_count, 
    init_water_crew_locs=['T_J8']*crew_count,
    init_transpo_crew_locs= ['T_J8']*crew_count
    )
# Out:
# Power repair crews successfully deployed.
# Water repair crews successfully deployed.
# Transportation repair crews successfully deployed.

# %% [markdown]
# ### Disrupted components and initial crew locations

# %%
model_plots.plot_disruptions_and_crews(micropolis_network)
# Out:
# {'power': ['P_L333', 'P_L56', 'P_L340', 'P_L325', 'P_L310'], 'water': ['W_PMA732', 'W_PMA802', 'W_PMA647', 'W_PMA549', 'W_PMA524'], 'transpo': ['T_L79', 'T_L72', 'T_L80', 'T_L86']}
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1247">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="196db219-a193-4dab-8360-94d5a9683bca" data-root-id="1215"></div>

# %% [markdown]
# ## Simulation of interdependent effects using a test scenario
# ### (a) Create NetworkRecovery

# %%
network_recovery = NetworkRecovery(micropolis_network, 
                                   sim_step=SIM_STEP, 
                                   pipe_close_policy="repair",
                                   pipe_closure_delay= 10, 
                                   line_close_policy="sensor_based_line_isolation",
                                   line_closure_delay= 10)

# %% [markdown]
# ### (b) Create a simulation object

# %%
bf_simulation = simulation.NetworkSimulation(network_recovery)

# %% [markdown]
# ### (c) Generation of random repair order

# %%
strategy = 'capacity'
capacity_strategy = strategies.HandlingCapacityStrategy(micropolis_network)
capacity_strategy.set_repair_order()
repair_order = capacity_strategy.get_repair_order()

import os
if not os.path.exists(MAIN_DIR/f"{network_dir}/{scenario_folder}/capacity"):
    os.makedirs(MAIN_DIR/f"{network_dir}/{scenario_folder}/capacity")

# %%
#Generate a random repair order
# repair_order = network_recovery.network.get_disrupted_components()
# repair_orders = pd.read_csv(MAIN_DIR/f"{network_dir}/{scenario_folder}/repair_strategies.csv")
# repair_order = list(repair_orders["capacity"])
#random.shuffle(repair_order)
print('Current repair order is {}'.format(repair_order))
# Out:
# Current repair order is ['T_L72', 'T_L80', 'T_L86', 'T_L79', 'P_L56', 'P_L325', 'P_L340', 'P_L310', 'P_L333', 'W_PMA802', 'W_PMA647', 'W_PMA524', 'W_PMA549', 'W_PMA732']

# %% [markdown]
# ### (d) Generation of event tables

# %%
bf_simulation.network_recovery.schedule_recovery(repair_order)
# Out:
# Repair T_L72: The transpo crew 1 is at T_J8 at t = 2.0 minutes. It takes 15 minutes to reach nearest node T_J35, the nearest transportation node from T_L72.
# Repair T_L80: The transpo crew 1 is at T_J35 at t = 377.0 minutes. It takes 11 minutes to reach nearest node T_J34, the nearest transportation node from T_L80.
# Repair T_L86: The transpo crew 1 is at T_J34 at t = 748.0 minutes. It takes 12 minutes to reach nearest node T_J39, the nearest transportation node from T_L86.
# Repair T_L79: The transpo crew 1 is at T_J39 at t = 1120.0 minutes. It takes 12 minutes to reach nearest node T_J40, the nearest transportation node from T_L79.
# Repair P_L56: The power crew 1 is at T_J8 at t = 2.0 minutes. It takes 18 minutes to reach nearest node T_J3, the nearest transportation node from P_L56.
# Repair P_L325: The power crew 1 is at T_J3 at t = 320.0 minutes. It takes 12 minutes to reach nearest node T_J29, the nearest transportation node from P_L325.
# Repair P_L340: The power crew 1 is at T_J29 at t = 632.0 minutes. It takes 13 minutes to reach nearest node T_J34, the nearest transportation node from P_L340.
# Repair P_L310: The power crew 1 is at T_J34 at t = 945.0 minutes. It takes 18 minutes to reach nearest node T_J2, the nearest transportation node from P_L310.
# Repair P_L333: The power crew 1 is at T_J2 at t = 1263.0 minutes. It takes 16 minutes to reach nearest node T_J28, the nearest transportation node from P_L333.
# Repair W_PMA802: The water crew 1 is at T_J8 at t = 2.0 minutes. It takes 21 minutes to reach nearest node T_J2, the nearest transportation node from W_PMA802.
# Repair W_PMA647: The water crew 1 is at T_J2 at t = 383.0 minutes. It takes 16 minutes to reach nearest node T_J28, the nearest transportation node from W_PMA647.
# Repair W_PMA524: The water crew 1 is at T_J28 at t = 759.0 minutes. It takes 12 minutes to reach nearest node T_J29, the nearest transportation node from W_PMA524.
# Repair W_PMA549: The water crew 1 is at T_J29 at t = 1131.0 minutes. It takes 12 minutes to reach nearest node T_J4, the nearest transportation node from W_PMA549.
# Repair W_PMA732: The water crew 1 is at T_J4 at t = 1503.0 minutes. It takes 16 minutes to reach nearest node T_J34, the nearest transportation node from W_PMA732.
# All restoration actions are successfully scheduled.
# Total travel times: power: 77 mins, water: 77 min, transportation: 50 mins
# Total recovery times: power: 1500.0 mins, water: 1800.0 min, transportation: 1440.0 mins
# Scheduling recovery actions completed in 0.671875 seconds

# %%
#bf_simulation.network_recovery.event_table.to_csv("event_tbl.csv", sep = "\t", index = False)
bf_simulation.expand_event_table()

# %% [markdown]
# ### (e) Simulation of interdependent effects

# %%
resilience_metrics = bf_simulation.simulate_interdependent_effects(
    bf_simulation.network_recovery)
# Out:
# Time instances for which simulations will be performed:
#  [60, 180, 1020, 1260, 1380, 19140, 19260, 19380, 19980, 22500, 22620, 22740, 22860, 22980, 23100, 23340, 23940, 37860, 37980, 38100, 38700, 44820, 44940, 45060, 45420, 45540, 45660, 46260, 56580, 56700, 56820, 57780, 67140, 67260, 67380, 67740, 67860, 67980, 68580, 75660, 75780, 75900, 76740, 89460, 89580, 89700, 90060, 90180, 90300, 91140, 94620, 94740, 94860, 112620, 112740, 112860]
# Simulating network conditions until 60 s
# Simulation time:  60.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 60.0 and 180.0...
# ******************
#
# Simulating network conditions until 180 s
# Simulation time:  180.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 180.0 and 1020.0...
# The power Resilience Metric value based on ECS is 0.005 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.005 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 0.003 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 0.003 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 0.004
# The weighted AUC value based on PCS is 0.004
# ******************
#
# Simulating network conditions until 1020 s
# Simulation time:  1020.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 1020.0 and 1260.0...
# The power Resilience Metric value based on ECS is 0.068 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.077 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 0.093 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 0.085 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 0.0805
# The weighted AUC value based on PCS is 0.081
# ******************
#
# Simulating network conditions until 1260 s
# Simulation time:  1260.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 1260.0 and 1380.0...
# The power Resilience Metric value based on ECS is 0.086 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.098 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 0.119 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 0.108 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 0.1025
# The weighted AUC value based on PCS is 0.10300000000000001
# ******************
#
# Simulating network conditions until 1380 s
# Simulation time:  1380.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 1380.0 and 19140.0...
# The power Resilience Metric value based on ECS is 0.095 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 0.108 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 0.131 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 0.119 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 0.113
# The weighted AUC value based on PCS is 0.11349999999999999
# ******************
#
# Simulating network conditions until 19140 s
# Simulation time:  19140.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 19140.0 and 19260.0...
# The power Resilience Metric value based on ECS is 1.429 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 1.635 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 1.331 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 0.963 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 1.38
# The weighted AUC value based on PCS is 1.299
# ******************
#
# Simulating network conditions until 19260 s
# Simulation time:  19260.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 19260.0 and 19380.0...
# The power Resilience Metric value based on ECS is 1.436 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 1.642 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 1.361 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 0.993 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 1.3984999999999999
# The weighted AUC value based on PCS is 1.3175
# ******************
#
# Simulating network conditions until 19380 s
# Simulation time:  19380.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 19380.0 and 19980.0...
# The power Resilience Metric value based on ECS is 1.439 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 1.644 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 1.381 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 1.013 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 1.4100000000000001
# The weighted AUC value based on PCS is 1.3285
# ******************
#
# Simulating network conditions until 19980 s
# Simulation time:  19980.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 19980.0 and 22500.0...
# The power Resilience Metric value based on ECS is 1.456 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 1.657 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 1.481 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 1.11 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 1.4685000000000001
# The weighted AUC value based on PCS is 1.3835000000000002
# ******************
#
# Simulating network conditions until 22500 s
# Simulation time:  22500.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 22500.0 and 22620.0...
# The power Resilience Metric value based on ECS is 1.529 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 1.71 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 1.904 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 1.526 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 1.7165
# The weighted AUC value based on PCS is 1.6179999999999999
# ******************
#
# Simulating network conditions until 22620 s
# Simulation time:  22620.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 22620.0 and 22740.0...
# The power Resilience Metric value based on ECS is 1.532 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 1.713 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 1.924 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 1.547 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 1.728
# The weighted AUC value based on PCS is 1.63
# ******************
#
# Simulating network conditions until 22740 s
# Simulation time:  22740.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 22740.0 and 22860.0...
# The power Resilience Metric value based on ECS is 1.536 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 1.715 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 1.945 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 1.568 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 1.7405
# The weighted AUC value based on PCS is 1.6415000000000002
# ******************
#
# Simulating network conditions until 22860 s
# Simulation time:  22860.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 22860.0 and 22980.0...
# The power Resilience Metric value based on ECS is 1.539 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 1.718 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 1.966 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 1.588 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 1.7525
# The weighted AUC value based on PCS is 1.653
# ******************
#
# Simulating network conditions until 22980 s
# Simulation time:  22980.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 22980.0 and 23100.0...
# The power Resilience Metric value based on ECS is 1.543 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 1.721 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 1.988 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 1.61 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 1.7654999999999998
# The weighted AUC value based on PCS is 1.6655000000000002
# ******************
#
# Simulating network conditions until 23100 s
# Simulation time:  23100.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 23100.0 and 23340.0...
# The power Resilience Metric value based on ECS is 1.546 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 1.723 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 2.014 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 1.636 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 1.7799999999999998
# The weighted AUC value based on PCS is 1.6795
# ******************
#
# Simulating network conditions until 23340 s
# Simulation time:  23340.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 23340.0 and 23940.0...
# The power Resilience Metric value based on ECS is 1.553 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 1.728 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 2.066 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 1.687 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 1.8094999999999999
# The weighted AUC value based on PCS is 1.7075
# ******************
#
# Simulating network conditions until 23940 s
# Simulation time:  23940.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 23940.0 and 37860.0...
# The power Resilience Metric value based on ECS is 1.57 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 1.741 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 2.192 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 1.812 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 1.8810000000000002
# The weighted AUC value based on PCS is 1.7765
# ******************
#
# Simulating network conditions until 37860 s
# Simulation time:  37860.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 37860.0 and 37980.0...
# The power Resilience Metric value based on ECS is 1.971 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.036 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 3.65 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 3.48 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 2.8105
# The weighted AUC value based on PCS is 2.758
# ******************
#
# Simulating network conditions until 37980 s
# Simulation time:  37980.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 37980.0 and 38100.0...
# The power Resilience Metric value based on ECS is 1.974 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.038 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 3.663 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 3.494 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 2.8185
# The weighted AUC value based on PCS is 2.766
# ******************
#
# Simulating network conditions until 38100 s
# Simulation time:  38100.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 38100.0 and 38700.0...
# The power Resilience Metric value based on ECS is 1.977 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.04 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 3.675 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 3.509 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 2.826
# The weighted AUC value based on PCS is 2.7744999999999997
# ******************
#
# Simulating network conditions until 38700 s
# Simulation time:  38700.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 38700.0 and 44820.0...
# The power Resilience Metric value based on ECS is 1.99 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.049 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 3.737 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 3.582 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 2.8635
# The weighted AUC value based on PCS is 2.8155
# ******************
#
# Simulating network conditions until 44820 s
# Simulation time:  44820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 44820.0 and 44940.0...
# The power Resilience Metric value based on ECS is 2.126 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.136 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 4.371 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 4.325 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 3.2485
# The weighted AUC value based on PCS is 3.2305
# ******************
#
# Simulating network conditions until 44940 s
# Simulation time:  44940.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 44940.0 and 45060.0...
# The power Resilience Metric value based on ECS is 2.128 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.137 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 4.384 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 4.339 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 3.2560000000000002
# The weighted AUC value based on PCS is 3.2380000000000004
# ******************
#
# Simulating network conditions until 45060 s
# Simulation time:  45060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 45060.0 and 45420.0...
# The power Resilience Metric value based on ECS is 2.131 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.139 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 4.397 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 4.354 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 3.2640000000000002
# The weighted AUC value based on PCS is 3.2465
# ******************
#
# Simulating network conditions until 45420 s
# Simulation time:  45420.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 45420.0 and 45540.0...
# The power Resilience Metric value based on ECS is 2.139 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.144 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 4.434 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 4.398 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 3.2865
# The weighted AUC value based on PCS is 3.271
# ******************
#
# Simulating network conditions until 45540 s
# Simulation time:  45540.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 45540.0 and 45660.0...
# The power Resilience Metric value based on ECS is 2.142 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.146 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 4.447 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 4.413 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 3.2945
# The weighted AUC value based on PCS is 3.2795
# ******************
#
# Simulating network conditions until 45660 s
# Simulation time:  45660.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 45660.0 and 46260.0...
# The power Resilience Metric value based on ECS is 2.144 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.147 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 4.459 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 4.427 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 3.3015
# The weighted AUC value based on PCS is 3.287
# ******************
#
# Simulating network conditions until 46260 s
# Simulation time:  46260.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 46260.0 and 56580.0...
# The power Resilience Metric value based on ECS is 2.157 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.156 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 4.522 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 4.5 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 3.3395
# The weighted AUC value based on PCS is 3.3280000000000003
# ******************
#
# Simulating network conditions until 56580 s
# Simulation time:  56580.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 56580.0 and 56700.0...
# The power Resilience Metric value based on ECS is 2.386 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.303 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 5.589 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 5.726 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 3.9875000000000003
# The weighted AUC value based on PCS is 4.0145
# ******************
#
# Simulating network conditions until 56700 s
# Simulation time:  56700.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 56700.0 and 56820.0...
# The power Resilience Metric value based on ECS is 2.388 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.304 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 5.602 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 5.741 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 3.995
# The weighted AUC value based on PCS is 4.0225
# ******************
#
# Simulating network conditions until 56820 s
# Simulation time:  56820.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 56820.0 and 57780.0...
# The power Resilience Metric value based on ECS is 2.39 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.305 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 5.615 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 5.756 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 4.0025
# The weighted AUC value based on PCS is 4.0305
# ******************
#
# Simulating network conditions until 57780 s
# Simulation time:  57780.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 57780.0 and 67140.0...
# The power Resilience Metric value based on ECS is 2.402 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.313 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 5.721 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 5.876 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 4.0615000000000006
# The weighted AUC value based on PCS is 4.0945
# ******************
#
# Simulating network conditions until 67140 s
# Simulation time:  67140.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 67140.0 and 67260.0...
# The power Resilience Metric value based on ECS is 2.527 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.394 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 6.773 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 7.044 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 4.65
# The weighted AUC value based on PCS is 4.718999999999999
# ******************
#
# Simulating network conditions until 67260 s
# Simulation time:  67260.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 67260.0 and 67380.0...
# The power Resilience Metric value based on ECS is 2.529 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.395 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 6.787 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 7.059 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 4.6579999999999995
# The weighted AUC value based on PCS is 4.727
# ******************
#
# Simulating network conditions until 67380 s
# Simulation time:  67380.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 67380.0 and 67740.0...
# The power Resilience Metric value based on ECS is 2.53 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.396 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 6.8 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 7.073 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 4.665
# The weighted AUC value based on PCS is 4.734500000000001
# ******************
#
# Simulating network conditions until 67740 s
# Simulation time:  67740.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 67740.0 and 67860.0...
# The power Resilience Metric value based on ECS is 2.535 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.399 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 6.84 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 7.117 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 4.6875
# The weighted AUC value based on PCS is 4.758
# ******************
#
# Simulating network conditions until 67860 s
# Simulation time:  67860.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 67860.0 and 67980.0...
# The power Resilience Metric value based on ECS is 2.537 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.4 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 6.853 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 7.131 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 4.695
# The weighted AUC value based on PCS is 4.7655
# ******************
#
# Simulating network conditions until 67980 s
# Simulation time:  67980.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 67980.0 and 68580.0...
# The power Resilience Metric value based on ECS is 2.538 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.401 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 6.866 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 7.146 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 4.702
# The weighted AUC value based on PCS is 4.7735
# ******************
#
# Simulating network conditions until 68580 s
# Simulation time:  68580.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 68580.0 and 75660.0...
# The power Resilience Metric value based on ECS is 2.546 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.406 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 6.93 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 7.215 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 4.7379999999999995
# The weighted AUC value based on PCS is 4.8105
# ******************
#
# Simulating network conditions until 75660 s
# Simulation time:  75660.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 75660.0 and 75780.0...
# The power Resilience Metric value based on ECS is 2.641 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.467 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.426 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 7.764 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.0335
# The weighted AUC value based on PCS is 5.1155
# ******************
#
# Simulating network conditions until 75780 s
# Simulation time:  75780.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 75780.0 and 75900.0...
# The power Resilience Metric value based on ECS is 2.642 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.467 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.43 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 7.769 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.036
# The weighted AUC value based on PCS is 5.118
# ******************
#
# Simulating network conditions until 75900 s
# Simulation time:  75900.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 75900.0 and 76740.0...
# The power Resilience Metric value based on ECS is 2.643 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.468 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.435 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 7.774 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.039
# The weighted AUC value based on PCS is 5.121
# ******************
#
# Simulating network conditions until 76740 s
# Simulation time:  76740.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 76740.0 and 89460.0...
# The power Resilience Metric value based on ECS is 2.649 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.472 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.466 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 7.809 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.0575
# The weighted AUC value based on PCS is 5.1405
# ******************
#
# Simulating network conditions until 89460 s
# Simulation time:  89460.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 89460.0 and 89580.0...
# The power Resilience Metric value based on ECS is 2.733 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.526 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.731 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 8.115 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.232
# The weighted AUC value based on PCS is 5.3205
# ******************
#
# Simulating network conditions until 89580 s
# Simulation time:  89580.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 89580.0 and 89700.0...
# The power Resilience Metric value based on ECS is 2.734 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.527 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.733 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 8.116 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.233499999999999
# The weighted AUC value based on PCS is 5.3215
# ******************
#
# Simulating network conditions until 89700 s
# Simulation time:  89700.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 89700.0 and 90060.0...
# The power Resilience Metric value based on ECS is 2.735 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.527 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.734 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 8.118 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.2345
# The weighted AUC value based on PCS is 5.3225
# ******************
#
# Simulating network conditions until 90060 s
# Simulation time:  90060.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 90060.0 and 90180.0...
# The power Resilience Metric value based on ECS is 2.737 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.529 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.737 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 8.122 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.237
# The weighted AUC value based on PCS is 5.3255
# ******************
#
# Simulating network conditions until 90180 s
# Simulation time:  90180.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 90180.0 and 90300.0...
# The power Resilience Metric value based on ECS is 2.738 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.529 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.739 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 8.123 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.2385
# The weighted AUC value based on PCS is 5.326
# ******************
#
# Simulating network conditions until 90300 s
# Simulation time:  90300.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 90300.0 and 91140.0...
# The power Resilience Metric value based on ECS is 2.739 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.53 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.74 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 8.125 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.2395
# The weighted AUC value based on PCS is 5.3275
# ******************
#
# Simulating network conditions until 91140 s
# Simulation time:  91140.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 91140.0 and 94620.0...
# The power Resilience Metric value based on ECS is 2.745 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.533 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.748 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 8.134 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.2465
# The weighted AUC value based on PCS is 5.3335
# ******************
#
# Simulating network conditions until 94620 s
# Simulation time:  94620.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 94620.0 and 94740.0...
# The power Resilience Metric value based on ECS is 2.768 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.548 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.764 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 8.152 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.266
# The weighted AUC value based on PCS is 5.35
# ******************
#
# Simulating network conditions until 94740 s
# Simulation time:  94740.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 94740.0 and 94860.0...
# The power Resilience Metric value based on ECS is 2.768 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.548 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.765 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 8.153 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.2665
# The weighted AUC value based on PCS is 5.3505
# ******************
#
# Simulating network conditions until 94860 s
# Simulation time:  94860.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 94860.0 and 112620.0...
# The power Resilience Metric value based on ECS is 2.768 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.548 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.765 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 8.153 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.2665
# The weighted AUC value based on PCS is 5.3505
# ******************
#
# Simulating network conditions until 112620 s
# Simulation time:  112620.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 112620.0 and 112740.0...
# The power Resilience Metric value based on ECS is 2.768 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.548 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.814 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 8.246 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.291
# The weighted AUC value based on PCS is 5.397
# ******************
#
# Simulating network conditions until 112740 s
# Simulation time:  112740.0 ; Hydraulic time step:  60.0 ; Report time step:  60
# Updating status of directly affected components between 112740.0 and 112860.0...
# The power Resilience Metric value based on ECS is 2.768 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.548 equivalent outage hours (EOH)
# The water Resilience Metric value based on ECS is 7.815 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 8.247 equivalent outage hours (EOH)
# The weighted AUC value based on ECS is 5.2915
# The weighted AUC value based on PCS is 5.3975
# ******************
#
# Simulation completed in 771 s

# %%
strategy = 'capacity'
bf_simulation.write_results(f"{MAIN_DIR}/{network_dir}/{scenario_folder}/{strategy}", 
                            resilience_metrics)
# Out:
# The simulation results successfully saved to ..\..\infrarisk\data\networks\micropolis\scenarios\track1\capacity

# %% [markdown]
# ### (f) Calculation of resilience metric

# %%
resilience_metrics.calculate_power_resmetric(network_recovery)
# Out:
# The power Resilience Metric value based on ECS is 2.768 equivalent outage hours (EOH)
# The power Resilience Metric value based on PCS is 2.548 equivalent outage hours (EOH)

# %%
resilience_metrics.calculate_water_resmetrics(network_recovery)
# Out:
# The water Resilience Metric value based on ECS is 7.815 equivalent outage hours (EOH)
# The water Resilience Metric value based on PCS is 8.247 equivalent outage hours (EOH)

# %% [markdown]
# # Plot network performance during the disruption

# %% [markdown]
# ### Overall system performance considering indirect effects

# %%
model_plots.plot_interdependent_effects(resilience_metrics, metric = 'pcs', title = False)

# %% [markdown]
# ### Building-level water outage hours

# %%
model_plots.plot_network_impact_map(resilience_metrics = resilience_metrics, 
                                    integrated_network = micropolis_network, 
                                    strategy = strategy, 
                                    node_prefix = "W_JTN", 
                                    infra = "water", 
                                    time_index = None)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1409">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="893d5ee2-bd3e-467a-8e77-35de5515a176" data-root-id="1410"></div>

# %% [markdown]
# ### Building-level power outage hours

# %%
model_plots.plot_network_impact_map(resilience_metrics, 
                                    integrated_network = micropolis_network, 
                                    strategy = strategy, 
                                    node_prefix= "P_LO", 
                                    infra = "power",
                                    time_index=None)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1585">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="91d18d3d-c1cf-4670-92c2-489aa8ba4d27" data-root-id="1586"></div>

# %%
power_df = resilience_metrics.power_demand_ratio.transpose()
power_df['name'] = power_df.index
power_df = power_df.reset_index(drop=True)

from shapely.geometry import Point
import bisect
import seaborn as sns

load_geo_dict = dict()
for index, load in enumerate(micropolis_network.pn.load.name):
    load_geo_dict[load] = Point([micropolis_network.pn.loads_geodata.x[index], 
                                 micropolis_network.pn.loads_geodata.y[index]])
power_df['geometry'] = power_df['name'].map(load_geo_dict)
power_gdf = gpd.GeoDataFrame(power_df, geometry='geometry')
power_gdf.columns = resilience_metrics.power_time_list + ['name', 'geometry']

# %%
water_df = resilience_metrics.water_demands_ratio.transpose()
water_df['name'] = water_df.index
water_df = water_df.reset_index(drop=True)

from shapely.geometry import Point, LineString
import bisect
from matplotlib.colors import ListedColormap

junc_geo_dict = dict()
demand_juncs = [x for x in resilience_metrics.water_demands_ratio.columns if x.startswith('W_JTN')]
for index, junc in enumerate(demand_juncs):
    junc_geo_dict[junc] = Point([micropolis_network.integrated_graph.nodes[junc]["coord"][0], 
                                micropolis_network.integrated_graph.nodes[junc]["coord"][1]])
water_df['geometry'] = water_df['name'].map(junc_geo_dict)
water_gdf = gpd.GeoDataFrame(water_df, geometry='geometry')
water_gdf.columns = resilience_metrics.water_time_list + ['name', 'geometry']
# Out:
# C:\Users\srijith\AppData\Roaming\Python\Python38\site-packages\pandas\core\dtypes\cast.py:118: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)

# %%
link_names = []
geometry = []
for start, end, data in micropolis_network.integrated_graph.edges(data=True):
    link_names.append(micropolis_network.integrated_graph.edges[start, end]['id'])
    geometry.append(LineString([Point(micropolis_network.integrated_graph.nodes[start]['coord'][0],
                            micropolis_network.integrated_graph.nodes[start]['coord'][1]),
                           Point(micropolis_network.integrated_graph.nodes[end]['coord'][0],
                           micropolis_network.integrated_graph.nodes[end]['coord'][1])]))

link_df = pd.DataFrame({'name': link_names, 'geometry': geometry})
link_gdf = gpd.GeoDataFrame(link_df, geometry='geometry')
# Out:
# C:\Users\srijith\AppData\Roaming\Python\Python38\site-packages\pandas\core\dtypes\cast.py:118: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   arr = construct_1d_object_array_from_listlike(values)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
import matplotlib.colors as colors
import matplotlib.patches as mpatches

time_intervals = range(0, int(resilience_metrics.water_time_list[-1]), 60)
for index, time in enumerate([33*60, 34*60, 35*60, 36*60]): #time_intervals:
#for index, time in enumerate(time_intervals[0:33]):
    print(index, time, end = ',')
    
    status = []
    for _, row in link_gdf.iterrows():
        
        if row['name'] in micropolis_network.disrupted_components.tolist():
            disrupt_time = network_recovery.event_table_wide[network_recovery.event_table_wide['component'] == row['name']]['disrupt_time'].values[0]
            repair_start = network_recovery.event_table_wide[network_recovery.event_table_wide['component'] == row['name']]['repair_start'].values[0]
            functional_start = network_recovery.event_table_wide[network_recovery.event_table_wide['component'] == row['name']]['functional_start'].values[0]
            #print(row['name'], disrupt_time, repair_start, functional_start)
            if disrupt_time/60 <= time < repair_start/60:
                status.append("Disrupted")
            elif repair_start/60 <= time < functional_start/60:
                status.append("Repairing")
            elif time >= functional_start/60:
                status.append("Restored")
            else:
                status.append("Unaffected")
        else:
            status.append("Unaffected")
    link_gdf['status'] = status
    
    
    fig, axes = plt.subplots(figsize=(16,10), nrows=2, ncols=2, gridspec_kw={'height_ratios': [1.75, 2], 'width_ratios': [0.75, 1]})
    #plt.subplots_adjust(bottom=0.3, top=0.7, hspace=0)
    
    sns.set_context("paper", font_scale=1.4)
    sns.set_style("white")
    column = time + 1

    cmap = colors.LinearSegmentedColormap.from_list(
        "", ['red', 'orange', 'yellow', 'limegreen']#["green", "yellow", "orange", "red"]
    )
    
    #Restoration
    ax = axes[1,0]
    stream = gpd.read_file(f"{MAIN_DIR}/{network_dir}/gis/streams_v1.shp")
    _ = stream.iloc[0:3].buffer(100).plot(color = 'lightblue', ax = ax)
        
    color_dict = {'Unaffected': 'silver', 'Disrupted': 'red', 'Repairing': 'orange', 'Restored': 'green'}
    link_gdf['colors'] = link_gdf['status'].map(color_dict)
    ax.set_axis_off()
    unaffected_link_gdf = link_gdf[link_gdf['status'] == 'Unaffected']
    affected_link_gdf = link_gdf[link_gdf['status'] != 'Unaffected']
    _ = unaffected_link_gdf.plot(ax = ax, linewidth = 1, legend = True, color = unaffected_link_gdf['colors'], alpha = 0.8)
    _ = affected_link_gdf.plot(ax = ax, linewidth = 2, legend = True, color = affected_link_gdf['colors'], alpha = 1)
    
    _ = ax.set_xlim(900,8000)
    _ = ax.set_ylim(2000, 6500)
    grey_patch = mpatches.Patch(color='silver', label='Unaffected', linewidth = 0.5)
    red_patch = mpatches.Patch(color='red', label='Disrupted', linewidth = 0.5)
    yellow_patch = mpatches.Patch(color='orange', label='Repairing', linewidth = 0.5)
    green_patch = mpatches.Patch(color='green', label='Restored', linewidth = 0.5)
       
    system_title = ax.set_title('Component status', fontsize = 16)
    _ = ax.legend(handles=[grey_patch, red_patch, yellow_patch, green_patch], loc = 'lower right', fontsize = 12)

    # water map 
    water_column = column
    ax = axes[0,1]
    _ = ax.set_axis_off()
    links = link_gdf.plot(ax=ax, color='grey', edgecolor='grey', linewidth=0.5, label = 'Infrastructure links', legend = False)
    water_plot = water_gdf.plot(ax=ax, marker = 's', column = water_column, cmap = cmap, 
                                vmin = 0, vmax = 1, linewidth=0.5, legend = True, 
                                legend_kwds={'shrink': 0.5, 'orientation': 'vertical', 'label': 'Satisfied water demand'})
    water_title = ax.set_title('Water supply performance', fontsize = 16)
    _ = ax.set_xlim(900,8000)
    _ = ax.set_ylim(2000, 6500)
    #axis backgroun
    ax.set_facecolor('grey')
    
    #power map
    ax = axes[1,1]
    _ = ax.set_axis_off()
    power_column = resilience_metrics.power_time_list[bisect.bisect(resilience_metrics.power_time_list, column)-1]
    links = link_gdf.plot(ax=ax, color='grey', edgecolor='grey', linewidth=0.5, label = 'Infrastructure links', legend = False)
    power_plot = power_gdf.plot(ax=ax, marker = 's', column = power_column, cmap = cmap, vmin = 0, vmax = 1, linewidth=0.5, legend = True,  
                                legend_kwds={'shrink': 0.5, 'orientation': 'vertical', 'label': 'Satisfied power demand'})
    power_title = ax.set_title('Power supply performance', fontsize = 16)
    _ = ax.set_xlim(900,8000)
    _ = ax.set_ylim(2000, 6500)
    
    # performance plots
    ax = axes[0,0]
    water_time = [x/60 for x in resilience_metrics.water_time_list if x <= column]
    water_perf = resilience_metrics.water_pcs_list[:bisect.bisect(resilience_metrics.water_time_list, column)]
    water_perf = water_perf[:(len(water_perf)-(index+1)*60)] + [1]*(index + 1)*60
    print(len(water_time), len(water_perf))
    if column not in resilience_metrics.power_time_list:
        power_time = [x/60 for x in resilience_metrics.power_time_list if x <= column] + [column/60]
        power_perf = resilience_metrics.power_pcs_list[:bisect.bisect(resilience_metrics.power_time_list, column)]
        power_perf.append(power_perf[-1])
    else:
        power_time = [x/60 for x in resilience_metrics.power_time_list if x <= column]
        power_perf = resilience_metrics.power_pcs_list[:bisect.bisect(resilience_metrics.power_time_list, column)]
    w_df = pd.DataFrame({'time': water_time, 'performance': water_perf})
    p_df = pd.DataFrame({'time': power_time, 'performance': power_perf})
    _  = w_df.plot(x = 'time', y = 'performance', ax = ax, color = 'tab:green', label = 'Water', 
                   linewidth = 2, drawstyle = 'steps-post', legend = True)
    _   = p_df.plot(x = 'time', y = 'performance', ax = ax, color = 'tab:red', label = 'Power', 
                    linewidth = 2, drawstyle = 'steps-post', legend = True)
    _  = ax.set_xlim(0, resilience_metrics.water_time_list[-1]/60)
    _  = ax.set_title('System-level Performance', fontsize = 16)
    _  = ax.set_ylim(0, 1)  
    _  = ax.set_ylabel('System Performance') 
    _  = ax.set_xlabel('Time (hours)') 
    _  = ax.text(0.675, 0.05, f'Time = {(column-1)/60} hours', horizontalalignment='left', 
                   verticalalignment='bottom', transform=ax.transAxes, 
                   fontsize=15, color='blue', fontweight='bold')
    _ = ax.legend(loc='upper right', fontsize = 12)
    
    fig.tight_layout()
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    
    fig.savefig(os.path.join('jonas_plots', f'{(time)}.png'), dpi=150)
# Out:
# 0 1980,1982 1982
# 1 2040,2042 2042
# 2 2100,2102 2102
# 3 2160,2162 2162

# %%
import imageio
with imageio.get_writer('/path/to/movie.gif', mode='I') as writer:
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2840/4173768399.py in <module>
# ----> 1 import imageio
#       2 with imageio.get_writer('/path/to/movie.gif', mode='I') as writer:
#       3     for filename in filenames:
#       4         image = imageio.imread(filename)
#       5         writer.append_data(image)
#
# ModuleNotFoundError: No module named 'imageio'

# %% [markdown]
# End of the notebook

# %%
micropolis_network.disruptive_events
# Out:
#    time_stamp components  fail_perc
# 0        6000   W_PMA640         50
# 1        6000   W_PMA507         50
# 2        6000   W_PMA705         50
# 3        6000       P_L3         50
# 4        6000     P_L104         50
# 5        6000     P_L140         50
# 6        6000     P_L252         50
# 7        6000     P_L376         50
# 8        6000     T_L179         50
# 9        6000     T_L187         50
